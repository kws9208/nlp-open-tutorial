# %% [markdown]
# #Fashion MNIST classification with CNN

# %% [markdown]
# Dataset load
#
# torchvision과 transforms를 이용한 dataset 구축
#
# torchvision.datasets.CIFAR10()를 이용하여 array형태의 학습데이터셋을 반환하는 torch.utils.data.Dataset클래스 load
# torchvision.transforms를 이용하여 해당 데이터를 Tensor로 변환하고 Normalize하여 값을 스케일링 한다.
#
# 다음 doc참조:
# FashionMNIST:https://pytorch.org/vision/stable/generated/torchvision.datasets.FashionMNIST.html
# transforms: https://pytorch.org/vision/stable/transforms.html

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# load할 dataset에 사전작업될 이미지 전처리
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

# torchvision을 통한 dataset load
trainDataset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
testDataset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

for i in trainDataset:
  print(i[0].shape)
  print(i[1])
  break

# batch processing을 위한 dataloader 구성
batch_size = 20
trainDataloader = DataLoader(trainDataset, batch_size, shuffle=True)
testDataloader = DataLoader(testDataset, batch_size, shuffle=False)
for i in trainDataloader:
  print(i[0].shape)
  print(i[1].shape)
  break


print(len(trainDataset))
print(len(testDataset))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:06<00:00, 27237130.23it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# torch.Size([3, 32, 32])
# 6
# torch.Size([20, 3, 32, 32])
# torch.Size([20])
# 50000
# 10000

# %%
import matplotlib.pyplot as plt
import numpy as np

# 이미지를 보여주기 위한 함수

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# 학습용 이미지를 무작위로 가져오기
dataiter = iter(trainDataloader)
images, labels = next(dataiter)

# 이미지 보여주기
imshow(torchvision.utils.make_grid(images))
# 정답(label) 출력
print(' '.join('%5s' % labels[j] for j in range(batch_size)))
# Out:
# tensor(3) tensor(5) tensor(8) tensor(6) tensor(6) tensor(7) tensor(2) tensor(0) tensor(1) tensor(5) tensor(5) tensor(3) tensor(2) tensor(6) tensor(5) tensor(5) tensor(9) tensor(9) tensor(5) tensor(3)

# %% [markdown]
# Model 선언
# nn.Module를 통해 모델의 구조결정
#
# CNN 기반의 모델을 선언한다.
# 모델의 구조는
# LeNet5와 동일한 형태로 구성하며 input data의 channel수는 3으로 가정한다.
#
#
# 각 오브젝트의 입력과 선언은 다음 doc 참조:
# Conv2d: https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
# AvgPool2d: https://pytorch.org/docs/stable/generated/torch.nn.AvgPool2d.html
# Linear: https://pytorch.org/docs/stable/generated/torch.nn.Linear.html

# %%
import torch.nn as nn


class myModel(nn.Module):
    def __init__(self):
      super().__init__()
      self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5)
      self.maxpool = nn.MaxPool2d(2, 2)
      self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5)
      self.conv3 = nn.Conv2d(in_channels=16, out_channels=120, kernel_size=5)
      self.linear1 = nn.Linear(120*1*1, 100)
      self.linear2 = nn.Linear(100, 10)
      self.relu = nn.ReLU()

    def forward(self, x):
      # N * 3 * 32 * 32
      x = self.conv1(x)
      # N * 6 * 28 * 28
      x = self.relu(x)
      x = self.maxpool(x)
      # N * 6 * 14 * 14
      x = self.conv2(x)
      # N * 16 * (14-5) +1 * (14-5) +1 = N * 16 * 10 * 10
      x = self.relu(x)
      x = self.maxpool(x)
      # N * 16 * 5 * 5
      x = self.conv3(x)
      # N * 120 * 1 * 1
      x = self.relu(x)
      x = x.reshape(-1, 120 * 1 * 1)
      x = self.linear1(x)
      x = self.relu(x)
      x = self.linear2(x)
      return x

model = myModel().cuda()

for i in trainDataloader:
  data = i[0].cuda()
  target = i[1].cuda()

  print(model(data).shape)
  break
# Out:
# torch.Size([20, 10])

# %% [markdown]
# 작성한 dataset과 model을 이용하여 딥러닝 프로세스 구현
#
# pytorch 딥러닝 프로세스
# 1. dataset, model선언
# 2. dataset과 model을 통한 결과 예측
# 3. 예측된 결과를 통해 **loss**연산 및 **loss.backward**
# 4. **optimizer.step()**를 사용하여 graident update
#
# 주요 오브젝트
# torch.nn.CrossEntropyLoss: 문장 분류를 위한 loss 수행
# torch.optim.Adam: Adam optimizer를 통해 gradient update를 수행하는 class
#
# 각 오브젝트의 입력과 선언은 다음 doc 참조:
# CrossEntropyLoss: https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
# Adam: https://pytorch.org/docs/stable/generated/torch.optim.Adam.html

# %%
from torch.optim import Adam
from torch.nn import CrossEntropyLoss

# 학습을 위한 optimizer와 loss function 설정
optimizer = Adam(model.parameters(), lr=0.001)
lf = CrossEntropyLoss()
# model.cuda()

# 100번의 에폭을 실행
for e in range(100):
  print("\n\nepoch ", e)
  epoch_loss = 0
  train_correct = 0

  # 선언한 모델 오브젝트를 학습가능한 상태로 변경
  model.train()

  # 모든 학습데이터에 대해서 학습
  for i in trainDataloader:
    # 매 배치에 대한 gradient계산 이전에 optimizer에 저장된 이전 batch에 gradient를 삭제(초기화)
    optimizer.zero_grad()

    data = i[0].cuda()
    target = i[1].cuda()

    # 결과 도출 및 정답수 연산
    output = model(data)
    pred_label = torch.argmax(output, dim=-1)
    train_correct += sum(pred_label == target.reshape(-1))

    # loss연산
    loss = lf(output, target)

    #loss backpropagation
    loss.backward()

    # gradient update
    optimizer.step()

    epoch_loss += loss.item()

  print("train loss", epoch_loss/len(trainDataloader))
  print("train acc", train_correct/len(trainDataset))

  # model이 학습되지 않는 상태로 변경
  model.eval()

  test_loss = 0
  test_correct = 0

  # gradient를 계산하지 않도록 하여 cost낭비 방지
  with torch.no_grad():
    # 모든 test dataset에 대해서 결과연산
    for i in testDataloader:
      data = i[0].cuda()
      target = i[1].cuda()

      output = model(data)

      loss = lf(output, target)
      pred_label = torch.argmax(output, dim = -1)
      test_correct += sum(pred_label == target.reshape(-1))
      test_loss += loss.item()

  print("test loss", test_loss/len(testDataloader))
  print("test acc", test_correct/len(testDataset))
# Out:
# epoch  0
# train loss 1.278491546702385
# train acc tensor(0.5416, device='cuda:0')
# test loss 1.2762317478656768
# test acc tensor(0.5404, device='cuda:0')
#
#
# epoch  1
# train loss 1.170783366060257
# train acc tensor(0.5823, device='cuda:0')
# test loss 1.1646962468624116
# test acc tensor(0.5852, device='cuda:0')
#
#
# epoch  2
# train loss 1.0899504586219788
# train acc tensor(0.6137, device='cuda:0')
# test loss 1.1404343707561493
# test acc tensor(0.5949, device='cuda:0')
#
#
# epoch  3
# train loss 1.0173622871518135
# train acc tensor(0.6415, device='cuda:0')
# test loss 1.1192382797002793
# test acc tensor(0.6074, device='cuda:0')
#
#
# epoch  4
# train loss 0.9697965681433678
# train acc tensor(0.6593, device='cuda:0')
# test loss 1.1052676399350165
# test acc tensor(0.6170, device='cuda:0')
#
#
# epoch  5
# train loss 0.9240377079248429
# train acc tensor(0.6735, device='cuda:0')
# test loss 1.0906780181527138
# test acc tensor(0.6240, device='cuda:0')
#
#
# epoch  6
# train loss 0.882790498483181
# train acc tensor(0.6873, device='cuda:0')
# test loss 1.0863072221875192
# test acc tensor(0.6224, device='cuda:0')
#
#
# epoch  7
# train loss 0.8459220956861973
# train acc tensor(0.7002, device='cuda:0')
# test loss 1.1148227578997612
# test acc tensor(0.6203, device='cuda:0')
#
#
# epoch  8
# train loss 0.8133542633891105
# train acc tensor(0.7114, device='cuda:0')
# test loss 1.071558899998665
# test acc tensor(0.6325, device='cuda:0')
#
#
# epoch  9
# train loss 0.7843879057943821
# train acc tensor(0.7214, device='cuda:0')
# test loss 1.1238043923377992
# test acc tensor(0.6207, device='cuda:0')
#
#
# epoch  10
# train loss 0.7615765048801899
# train acc tensor(0.7293, device='cuda:0')
# test loss 1.1078076516985893
# test acc tensor(0.6316, device='cuda:0')
#
#
# epoch  11
# train loss 0.7347773965418338
# train acc tensor(0.7388, device='cuda:0')
# test loss 1.1802320826053618
# test acc tensor(0.6159, device='cuda:0')
#
#
# epoch  12
# train loss 0.7120006154835224
# train acc tensor(0.7439, device='cuda:0')
# test loss 1.1583615193367005
# test acc tensor(0.6216, device='cuda:0')
#
#
# epoch  13
# train loss 0.6919641268610954
# train acc tensor(0.7513, device='cuda:0')
# test loss 1.1936662104129792
# test acc tensor(0.6257, device='cuda:0')
#
#
# epoch  14
# train loss 0.6670862908422946
# train acc tensor(0.7611, device='cuda:0')
# test loss 1.219088158905506
# test acc tensor(0.6162, device='cuda:0')
#
#
# epoch  15
# train loss 0.6523999360769988
# train acc tensor(0.7669, device='cuda:0')
# test loss 1.2137613095641135
# test acc tensor(0.6239, device='cuda:0')
#
#
# epoch  16
# train loss 0.6360006328940392
# train acc tensor(0.7739, device='cuda:0')
# test loss 1.2693188296556472
# test acc tensor(0.6206, device='cuda:0')
#
#
# epoch  17
# train loss 0.6170118153005838
# train acc tensor(0.7777, device='cuda:0')
# test loss 1.280407665491104
# test acc tensor(0.6220, device='cuda:0')
#
#
# epoch  18
# train loss 0.5998202033877372
# train acc tensor(0.7847, device='cuda:0')
# test loss 1.3554279792308808
# test acc tensor(0.6072, device='cuda:0')
#
#
# epoch  19
# train loss 0.5904876343041658
# train acc tensor(0.7864, device='cuda:0')
# test loss 1.3449066964387895
# test acc tensor(0.6123, device='cuda:0')
#
#
# epoch  20
# train loss 0.5701773654252291
# train acc tensor(0.7931, device='cuda:0')
# test loss 1.414727334022522
# test acc tensor(0.6164, device='cuda:0')
#
#
# epoch  21
# train loss 0.557688785263896
# train acc tensor(0.7993, device='cuda:0')
# test loss 1.4579647412896157
# test acc tensor(0.6023, device='cuda:0')
#
#
# epoch  22
# train loss 0.5478414277777076
# train acc tensor(0.8005, device='cuda:0')
# test loss 1.447647057890892
# test acc tensor(0.6047, device='cuda:0')
#
#
# epoch  23
# train loss 0.5342654773756862
# train acc tensor(0.8053, device='cuda:0')
# test loss 1.514398020505905
# test acc tensor(0.6081, device='cuda:0')
#
#
# epoch  24
# train loss 0.5226165022835135
# train acc tensor(0.8120, device='cuda:0')
# test loss 1.531284019291401
# test acc tensor(0.6062, device='cuda:0')
#
#
# epoch  25
# train loss 0.5100361540347338
# train acc tensor(0.8156, device='cuda:0')
# test loss 1.5710062022209168
# test acc tensor(0.6061, device='cuda:0')
#
#
# epoch  26
# train loss 0.4984358521550894
# train acc tensor(0.8180, device='cuda:0')
# test loss 1.5790459685325622
# test acc tensor(0.6074, device='cuda:0')
#
#
# epoch  27
# train loss 0.4873234290137887
# train acc tensor(0.8244, device='cuda:0')
# test loss 1.6935446378588677
# test acc tensor(0.6016, device='cuda:0')
#
#
# epoch  28
# train loss 0.4788728027760982
# train acc tensor(0.8275, device='cuda:0')
# test loss 1.6419119048118591
# test acc tensor(0.5999, device='cuda:0')
#
#
# epoch  29
# train loss 0.46965637864917514
# train acc tensor(0.8300, device='cuda:0')
# test loss 1.7146535338759423
# test acc tensor(0.6020, device='cuda:0')
#
#
# epoch  30
# train loss 0.46335318685621024
# train acc tensor(0.8299, device='cuda:0')
# test loss 1.7334395946264267
# test acc tensor(0.5959, device='cuda:0')
#
#
# epoch  31
# train loss 0.4532732933498919
# train acc tensor(0.8350, device='cuda:0')
# test loss 1.7766990621089935
# test acc tensor(0.5989, device='cuda:0')
#
#
# epoch  32
# train loss 0.442806732288003
# train acc tensor(0.8377, device='cuda:0')
# test loss 1.8037057603001594
# test acc tensor(0.5960, device='cuda:0')
#
#
# epoch  33
# train loss 0.4359277162402868
# train acc tensor(0.8417, device='cuda:0')
# test loss 1.8479262274503707
# test acc tensor(0.5930, device='cuda:0')
#
#
# epoch  34
# train loss 0.42755879588648676
# train acc tensor(0.8459, device='cuda:0')
# test loss 1.8802437193393706
# test acc tensor(0.5983, device='cuda:0')
#
#
# epoch  35
# train loss 0.42350928217098116
# train acc tensor(0.8462, device='cuda:0')
# test loss 1.9321427256464958
# test acc tensor(0.5950, device='cuda:0')
#
#
# epoch  36
# train loss 0.4183231644302607
# train acc tensor(0.8467, device='cuda:0')
# test loss 1.9292898851931095
# test acc tensor(0.5925, device='cuda:0')
#
#
# epoch  37
# train loss 0.4101619842261076
# train acc tensor(0.8494, device='cuda:0')
# test loss 1.9456167090535164
# test acc tensor(0.5945, device='cuda:0')
#
#
# epoch  38
# train loss 0.4036437256798148
# train acc tensor(0.8540, device='cuda:0')
# test loss 1.9600884321928025
# test acc tensor(0.5961, device='cuda:0')
#
#
# epoch  39
# train loss 0.40030086303353307
# train acc tensor(0.8538, device='cuda:0')
# test loss 1.9856212600171566
# test acc tensor(0.5903, device='cuda:0')
#
#
# epoch  40
# train loss 0.3902902467817068
# train acc tensor(0.8570, device='cuda:0')
# test loss 2.054756515741348
# test acc tensor(0.5974, device='cuda:0')
#
#
# epoch  41
# train loss 0.38595969497188926
# train acc tensor(0.8594, device='cuda:0')
# test loss 2.091923129796982
# test acc tensor(0.5963, device='cuda:0')
#
#
# epoch  42
# train loss 0.3834844933822751
# train acc tensor(0.8618, device='cuda:0')
# test loss 2.1691184599399564
# test acc tensor(0.5932, device='cuda:0')
#
#
# epoch  43
# train loss 0.37636266775503757
# train acc tensor(0.8621, device='cuda:0')
# test loss 2.151027051448822
# test acc tensor(0.5898, device='cuda:0')
#
#
# epoch  44
# train loss 0.37233432617783546
# train acc tensor(0.8651, device='cuda:0')
# test loss 2.233481765836477
# test acc tensor(0.5905, device='cuda:0')
#
#
# epoch  45
# train loss 0.3663746419914067
# train acc tensor(0.8662, device='cuda:0')
# test loss 2.1463103225827216
# test acc tensor(0.5919, device='cuda:0')
#
#
# epoch  46
# train loss 0.36755903572514653
# train acc tensor(0.8656, device='cuda:0')
# test loss 2.2183712267279625
# test acc tensor(0.5879, device='cuda:0')
#
#
# epoch  47
# train loss 0.35731043431274595
# train acc tensor(0.8705, device='cuda:0')
# test loss 2.308858390152454
# test acc tensor(0.5883, device='cuda:0')
#
#
# epoch  48
# train loss 0.35447237823680044
# train acc tensor(0.8707, device='cuda:0')
# test loss 2.2483540984392167
# test acc tensor(0.5843, device='cuda:0')
#
#
# epoch  49
# train loss 0.34768473756462337
# train acc tensor(0.8735, device='cuda:0')
# test loss 2.3609174692034722
# test acc tensor(0.5827, device='cuda:0')
#
#
# epoch  50
# train loss 0.3479979471214116
# train acc tensor(0.8734, device='cuda:0')
# test loss 2.387012182235718
# test acc tensor(0.5837, device='cuda:0')
#
#
# epoch  51
# train loss 0.33788196394890546
# train acc tensor(0.8786, device='cuda:0')
# test loss 2.4063202301859854
# test acc tensor(0.5838, device='cuda:0')
#
#
# epoch  52
# train loss 0.33354322648812085
# train acc tensor(0.8788, device='cuda:0')
# test loss 2.5106282482147217
# test acc tensor(0.5883, device='cuda:0')
#
#
# epoch  53
# train loss 0.34009919498115776
# train acc tensor(0.8756, device='cuda:0')
# test loss 2.4229898385703565
# test acc tensor(0.5889, device='cuda:0')
#
#
# epoch  54
# train loss 0.3328191455360502
# train acc tensor(0.8782, device='cuda:0')
# test loss 2.501897421061993
# test acc tensor(0.5742, device='cuda:0')
#
#
# epoch  55
# train loss 0.3218970684304833
# train acc tensor(0.8829, device='cuda:0')
# test loss 2.5339138316363097
# test acc tensor(0.5858, device='cuda:0')
#
#
# epoch  56
# train loss 0.3235864560712129
# train acc tensor(0.8833, device='cuda:0')
# test loss 2.641504718661308
# test acc tensor(0.5867, device='cuda:0')
#
#
# epoch  57
# train loss 0.3240275460101664
# train acc tensor(0.8826, device='cuda:0')
# test loss 2.535162097364664
# test acc tensor(0.5832, device='cuda:0')
#
#
# epoch  58
# train loss 0.3234163298521191
# train acc tensor(0.8832, device='cuda:0')
# test loss 2.640314429283142
# test acc tensor(0.5834, device='cuda:0')
#
#
# epoch  59
# train loss 0.3109705007262528
# train acc tensor(0.8865, device='cuda:0')
# test loss 2.6385558710098267
# test acc tensor(0.5839, device='cuda:0')
#
#
# epoch  60
# train loss 0.30722807675637304
# train acc tensor(0.8869, device='cuda:0')
# test loss 2.6804234802722933
# test acc tensor(0.5850, device='cuda:0')
#
#
# epoch  61
# train loss 0.31076374288238584
# train acc tensor(0.8877, device='cuda:0')
# test loss 2.7135038994550706
# test acc tensor(0.5855, device='cuda:0')
#
#
# epoch  62
# train loss 0.3072268450122327
# train acc tensor(0.8892, device='cuda:0')
# test loss 2.7706323577463627
# test acc tensor(0.5801, device='cuda:0')
#
#
# epoch  63
# train loss 0.3064338252093643
# train acc tensor(0.8885, device='cuda:0')
# test loss 2.738799748227
# test acc tensor(0.5844, device='cuda:0')
#
#
# epoch  64
# train loss 0.2976280703809112
# train acc tensor(0.8920, device='cuda:0')
# test loss 2.791193134188652
# test acc tensor(0.5780, device='cuda:0')
#
#
# epoch  65
# train loss 0.30056278720274565
# train acc tensor(0.8933, device='cuda:0')
# test loss 2.814103855550289
# test acc tensor(0.5807, device='cuda:0')
#
#
# epoch  66
# train loss 0.2927838642708957
# train acc tensor(0.8946, device='cuda:0')
# test loss 2.8851163235902786
# test acc tensor(0.5768, device='cuda:0')
#
#
# epoch  67
# train loss 0.29423829468674956
# train acc tensor(0.8926, device='cuda:0')
# test loss 2.9117974715828896
# test acc tensor(0.5784, device='cuda:0')
#
#
# epoch  68
# train loss 0.29082281153127554
# train acc tensor(0.8953, device='cuda:0')
# test loss 2.959722888767719
# test acc tensor(0.5828, device='cuda:0')
#
#
# epoch  69
# train loss 0.28422893090527507
# train acc tensor(0.8970, device='cuda:0')
# test loss 3.0068250584602354
# test acc tensor(0.5820, device='cuda:0')
#
#
# epoch  70
# train loss 0.2888637600399554
# train acc tensor(0.8969, device='cuda:0')
# test loss 2.9259464311003685
# test acc tensor(0.5799, device='cuda:0')
#
#
# epoch  71
# train loss 0.27789009655974806
# train acc tensor(0.8998, device='cuda:0')
# test loss 2.9266889103651046
# test acc tensor(0.5778, device='cuda:0')
#
#
# epoch  72
# train loss 0.2908489080104977
# train acc tensor(0.8968, device='cuda:0')
# test loss 3.1342833271622657
# test acc tensor(0.5749, device='cuda:0')
#
#
# epoch  73
# train loss 0.27650987025089563
# train acc tensor(0.9006, device='cuda:0')
# test loss 3.07627711519599
# test acc tensor(0.5801, device='cuda:0')
#
#
# epoch  74
# train loss 0.2815405343828723
# train acc tensor(0.9000, device='cuda:0')
# test loss 3.055890201985836
# test acc tensor(0.5756, device='cuda:0')
#
#
# epoch  75
# train loss 0.27314553982596845
# train acc tensor(0.9018, device='cuda:0')
# test loss 3.130027078539133
# test acc tensor(0.5786, device='cuda:0')
#
#
# epoch  76
# train loss 0.280978411164321
# train acc tensor(0.9012, device='cuda:0')
# test loss 3.131780412375927
# test acc tensor(0.5758, device='cuda:0')
#
#
# epoch  77
# train loss 0.2718699190085754
# train acc tensor(0.9020, device='cuda:0')
# test loss 3.135119881764054
# test acc tensor(0.5863, device='cuda:0')
#
#
# epoch  78
# train loss 0.27120031471205874
# train acc tensor(0.9042, device='cuda:0')
# test loss 3.191414967149496
# test acc tensor(0.5793, device='cuda:0')
#
#
# epoch  79
# train loss 0.2710901151586324
# train acc tensor(0.9029, device='cuda:0')
# test loss 3.1903807432353495
# test acc tensor(0.5814, device='cuda:0')
#
#
# epoch  80
# train loss 0.26691126949992033
# train acc tensor(0.9059, device='cuda:0')
# test loss 3.2755470620393754
# test acc tensor(0.5825, device='cuda:0')
#
#
# epoch  81
# train loss 0.2670803568624426
# train acc tensor(0.9059, device='cuda:0')
# test loss 3.2791479442715645
# test acc tensor(0.5781, device='cuda:0')
#
#
# epoch  82
# train loss 0.2675593485765159
# train acc tensor(0.9050, device='cuda:0')
# test loss 3.223453220888972
# test acc tensor(0.5777, device='cuda:0')
#
#
# epoch  83
# train loss 0.26293997896444055
# train acc tensor(0.9062, device='cuda:0')
# test loss 3.241575966119766
# test acc tensor(0.5717, device='cuda:0')
#
#
# epoch  84
# train loss 0.2599278743723407
# train acc tensor(0.9065, device='cuda:0')
# test loss 3.294582207173109
# test acc tensor(0.5783, device='cuda:0')
#
#
# epoch  85
# train loss 0.2581393571132794
# train acc tensor(0.9073, device='cuda:0')
# test loss 3.330424089759588
# test acc tensor(0.5805, device='cuda:0')
#
#
# epoch  86
# train loss 0.27631096335737965
# train acc tensor(0.9027, device='cuda:0')
# test loss 3.3267490559369324
# test acc tensor(0.5784, device='cuda:0')
#
#
# epoch  87
# train loss 0.2642856450289954
# train acc tensor(0.9071, device='cuda:0')
# test loss 3.3436632821261885
# test acc tensor(0.5789, device='cuda:0')
#
#
# epoch  88
# train loss 0.25506852833516896
# train acc tensor(0.9107, device='cuda:0')
# test loss 3.4688410003483297
# test acc tensor(0.5762, device='cuda:0')
#
#
# epoch  89
# train loss 0.2605147310446948
# train acc tensor(0.9077, device='cuda:0')
# test loss 3.417239108771086
# test acc tensor(0.5732, device='cuda:0')
#
#
# epoch  90
# train loss 0.24374736007377507
# train acc tensor(0.9137, device='cuda:0')
# test loss 3.589805090665817
# test acc tensor(0.5777, device='cuda:0')
#
#
# epoch  91
# train loss 0.2569927712392993
# train acc tensor(0.9092, device='cuda:0')
# test loss 3.4295516481399537
# test acc tensor(0.5814, device='cuda:0')
#
#
# epoch  92
# train loss 0.2533152647949755
# train acc tensor(0.9109, device='cuda:0')
# test loss 3.5262927101552486
# test acc tensor(0.5765, device='cuda:0')
#
#
# epoch  93
# train loss 0.2501509369817562
# train acc tensor(0.9128, device='cuda:0')
# test loss 3.4733694986104964
# test acc tensor(0.5826, device='cuda:0')
#
#
# epoch  94
# train loss 0.24691809036275372
# train acc tensor(0.9125, device='cuda:0')
# test loss 3.5786046322584153
# test acc tensor(0.5732, device='cuda:0')
#
#
# epoch  95
# train loss 0.25152667582966387
# train acc tensor(0.9116, device='cuda:0')
# test loss 3.5634568853378297
# test acc tensor(0.5736, device='cuda:0')
#
#
# epoch  96
# train loss 0.23873547861119732
# train acc tensor(0.9169, device='cuda:0')
# test loss 3.5878666698038577
# test acc tensor(0.5766, device='cuda:0')
#
#
# epoch  97
# train loss 0.2427904606090102
# train acc tensor(0.9155, device='cuda:0')
# test loss 3.6307087531387805
# test acc tensor(0.5775, device='cuda:0')
#
#
# epoch  98
# train loss 0.24835513563239947
# train acc tensor(0.9120, device='cuda:0')
# test loss 3.640814513921738
# test acc tensor(0.5829, device='cuda:0')
#
#
# epoch  99
# train loss 0.24176195352640933
# train acc tensor(0.9142, device='cuda:0')
# test loss 3.665433063805103
# test acc tensor(0.5812, device='cuda:0')
